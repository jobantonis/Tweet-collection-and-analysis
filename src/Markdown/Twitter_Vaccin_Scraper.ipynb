# %% [markdown]
# # Twitter scraper COVID vaccine press conferences within the Netherlands

# %% [markdown]
# We built a Twitter scraper in order to find out the sentiment towards to COVID-19 vaccine in the Netherlands, within the time frames surrounding the Dutch governments' Press Conferences. Herewith we want to measure the influence of the regulations regarding COVID-19 on the attitude people have towards COVID-19 vaccines.
#
# Our scraper results in a CSV file, containing the following entities:
# - Dutch tweets containing the following keywords: *coronavaccin, corona_vaccin, covidvaccin, covid_vaccin, covid_vaccine, covidvaccine, coronavaccine, covid_vaccine*
# - Specific dates the tweets were posted (around the persconferences (3 days before and 3 days after), *datums + timeframe n.t.b. https://www.rijksoverheid.nl/onderwerpen/coronavirus-covid-19/coronavirus-beeld-en-video/videos-persconferenties*)
# - Content of the tweets
# - User ID *anoniem gemaakt d.m.v. ...*
#
# ##Datum nog veranderen!!!

# %% [markdown]
# For our code, we decided to use Selenium because Twitter is a dynamic webpage where we need to mimic scrolling like a Twitter user.
# Therefore, we first have to download and import some drivers and prerequisites.

# %%
import csv
import selenium.webdriver   
from getpass import getpass
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# Then, we wrote a function in order to get multiple tweets. We used the .find()-function in order to find specific elements in the source code of the website. Below, we inserted 2 pictures, showing examples of how we found the specific elements (for username and comment). The '.text'-function makes sure we copy the text belonging to the element we were looking for.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jobantonis/Tremendously-awesome-repository/main/Screenshot%202021-03-11%20at%2017.17.12.png" align="center" width=60%/>

# %%
def get_tweet_data(card):
    username = card.find_element_by_xpath('.//span').text
    try:
        handle = card.find_element_by_xpath('.//span[contains(text(), "@")]').text 
    except NoSuchElementException:
        return
    
    try:
        postdate = card.find_element_by_xpath('.//time').get_attribute('datetime')
    except NoSuchElementException:
        return
    
    comment = card.find_element_by_xpath('.//div[2]/div[2]/div[1]').text
    responding = card.find_element_by_xpath('.//div[2]/div[2]/div[2]').text
    #text = comment + responding
    reply_cnt = card.find_element_by_xpath('.//div[@data-testid="reply"]').text
    retweet_cnt = card.find_element_by_xpath('.//div[@data-testid="retweet"]').text
    like_cnt = card.find_element_by_xpath('.//div[@data-testid="like"]').text
    
    tweet = {'username':username, 
             'handle':handle, 
             'date': postdate,
             'comment': comment, 
             'responding': responding, 
             'reply_cnt':reply_cnt, 
             'retweet_cnt': retweet_cnt, 
             'like_cnt': like_cnt}
    return(tweet)

# %% [markdown]
# We use Selenium, and therefore have to choose a browser in which we are going to open Twitter. We decided to use Chrome, so we set our Driver to Chrome.

# %%
driver = selenium.webdriver.Chrome()

# %% [markdown]
# First, we navigate to the login page, after which our credentials are put in.

# %%
driver.get('https://twitter.com/login') 
driver.maximize_window()

username = driver.find_element_by_xpath('//input[@name="session[username_or_email]"]')
username.send_keys('Job_A98')

my_password = getpass() 

password = driver.find_element_by_xpath('//input[@name = "session[password]"]')
password.send_keys(my_password)
password.send_keys(Keys.RETURN) 
sleep(1)
# Out:
# ········

# %% [markdown]
# Then, we navigate to the search bar in the top right. There we fill in all relevant keywords, the time window selected (which is altered for a number of days aorund past COVID related press conferences) and specify to search for Dutch tweets only.

# %%
search_input = driver.find_element_by_xpath('//input[@aria-label="Search query"]')
search_input.send_keys('(vaccin OR vaccine OR coronavaccin OR corona_vaccin OR covidvaccin OR covid_vaccin OR corona_vaccine OR coronavaccine OR covidvaccine OR covid_vaccine) lang:nl until:2021-01-05 since:2021-01-03')
search_input.send_keys(Keys.RETURN)

# %% [markdown]
# Following the input of our query, we head to the "latest" tab in order to capture all historical tweets instead of just the popular ones.

# %%
driver.find_element_by_link_text('Latest').click()

# %% [markdown]
# Next, we want to fill the data with our input. Therefore, we create a list called 'data'. Furthermore, since it is a dynamic website which is accessed through scrolling through the site, we want to make sure we do not add the same tweets twice, therefore the function set(), called tweet_ids is added. Lastly, we added a function that executes the script and stops when we are at the last page.

# %%
data = [] #needed to fill a string with data
tweet_ids = set() #Used in order to mitigate scraping duplicate tweets caused by possible increasing number of tweets per scroll 
last_position = driver.execute_script("return window.pageYOffset;") #For tracking scroll position, breaking out of loop if end is reached
scrolling = True

# %% [markdown]
# While scrolling, we want to make sure to capture our data from the tweets we encounter. After that, we actually begin to scroll down the pages. Since we are aware that there is a possibility that our internet laggs in between because of poor internet connection, we made sure our scraper tries to scroll twice before it is disregarded.

# %%
while scrolling:
    
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]') #First div with which the scraper encounters a tweet
    for card in page_cards[-15:]: # used -15, since we assume there are 15 tweets loaded each time
        tweet = get_tweet_data(card) #get 15 tweets per reload
        if tweet not in data:
            data.append(tweet)    
        
 #       if tweet:
 #           tweet_id = tweet #make 1 tweet of the separate words used in the tweet
 #           if tweet_id not in tweet_ids: #Make sure you do not capture the same tweet twice, by only appending tweets that you haven't added before. 
 #               tweet_ids.add(tweet_id) #to the set() function we add tweet_ids
 #               data.append(tweet) #add tweets to data list

    scroll_attempt = 0 #used as sometimes due to lag scrolling will not register, so we allow for number of scroll attempts
    while True:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(1) #giving program time to load before scraping
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position: #breaks out of loop if current and last scroll positions are the same
            scroll_attempt += 1 
            #2 attempts to check if it is the end of the page, since it is also possible that the scraper laggs because of poor internet connection.
            if scroll_attempt >= 3: 
                scrolling = False
                break
            else: 
                sleep(2) 
        else:
            last_position = curr_position #makes sure the loop ends
            break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-31148e48db62> in <module>
# ----> 1 while scrolling:
#       2
#       3     page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]') #First div with which the scraper encounters a tweet
#       4     for card in page_cards[-15:]: # used -15, since we assume there are 15 tweets loaded each time
#       5         tweet = get_tweet_data(card) #get 15 tweets per reload
#
# NameError: name 'scrolling' is not defined

# %% [markdown]
# Copy the data to a CSV file, creating headers and writing data towards the file using the following code:

# %%
data
# Out:
# [{'username': 'Kim Verstraten',
#   'handle': '@kshesq',
#   'date': '2021-02-04T23:59:52.000Z',
#   'comment': 'Replying to \n@wmiddelkoop',
#   'responding': 'Dus waarom dat vaccin? Toevallig zit er een persoon achter die minder mensen op de wereld wil hebben genaamd Gates. Ga er maar vanuit dat dit vaccin voor sterilisatie zorgt. Gates heeft in Afrika 10 duizenden vrouwen ongevraagd gesteriliseerd met vaccinaties',
#   'reply_cnt': '1',
#   'retweet_cnt': '1',
#   'like_cnt': '3'},
#  {'username': 'Μανγειαβα',
#   'handle': '@manyavo',
#   'date': '2021-02-04T23:59:18.000Z',
#   'comment': 'Replying to \n@DevliegerErik\n @fuckroeper\n and 2 others',
#   'responding': 'Ruim 7000 bijwerkingen door vaccin. \n\nBron:lareb',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Tiemen Jan van Dijk',
#   'handle': '@TiemenJan',
#   'date': '2021-02-04T23:57:47.000Z',
#   'comment': 'Vreemd de hoofd van Jansen vaccin kraakt Sputnik V af en de directeur van Pfizer vind het serieus een interessant vaccin! Verschil tussen #Jinek en #Op1',
#   'responding': '',
#   'reply_cnt': '2',
#   'retweet_cnt': '',
#   'like_cnt': '2'},
#  {'username': 'Arek Dukiewicz',
#   'handle': '@ArekDukiewicz',
#   'date': '2021-02-04T23:57:39.000Z',
#   'comment': 'Ongepast neerbuigend, keer op keer.\n\nIneens lijkt Spoetnik V, dat Russische coronavaccin, zo gek nog niet. Kunnen wij dat ook bestellen? https://demorgen.be/ts-b799ba42 via \n@demorgen',
#   'responding': 'Ineens lijkt Spoetnik V, dat Russische coronavaccin, zo gek nog niet. Kunnen wij dat ook bestellen?\nPlots is er in de EU belangstelling voor het Russische vaccin. Na problemen met het eigen programma en een bemoedigende publicatie (effectiviteit: ...\ndemorgen.be',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Kim Verstraten',
#   'handle': '@kshesq',
#   'date': '2021-02-04T23:56:54.000Z',
#   'comment': 'Replying to \n@trias_politica',
#   'responding': 'Wat wil je nou Jean, rest van je leven 1,5m en masker op? Gaat gewoon gebeuren zelfs met vaccin verplicht.',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'R. Hartman',
#   'handle': '@r_hartman',
#   'date': '2021-02-04T23:56:44.000Z',
#   'comment': 'Replying to \n@geledraak\n @woukevscherrenb\n and \n@hdalmolen',
#   'responding': "So what? Er zijn ook geen vaccins.\nDie zijn ook helemaal niet nodig.\n\nWat door de media (NIÉT door de fabrikant!) 'vaccin' genoemd wordt is gen-therapie. Je wordt aangesloten op het Internet of Things en 24/7 gemonitord. De 'covid' leugen moet zorgen dat je die prik gaat halen.",
#   'reply_cnt': '1',
#   'retweet_cnt': '1',
#   'like_cnt': ''},
#  {'username': 'Roelf Turksema',
#   'handle': '@RoelfTurksema',
#   'date': '2021-02-04T23:56:17.000Z',
#   'comment': 'Replying to \n@patricksavalle',
#   'responding': 'Houd je een beetje bij hoe zo een "geweldig succes" het Pfizer vaccin is na 2 miljoen tweede en 3.5 miljoen eerste injecties? Het aantal positieven stijgt weer..... 2x zoveel gevallen als hier momenteel. Mmmmh.',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Jan Heyn',
#   'handle': '@HeynJan',
#   'date': '2021-02-04T23:54:43.000Z',
#   'comment': 'Replying to \n@plaisier_peter\n and \n@IntrinsicAddict',
#   'responding': 'Bill Gates heeft enkel aan laboratoria die onderzoek naar een vaccin deden en doen geschonken. Die heeft daar geen enkel belang bij.\nDat soort hoax verhalen slaan als een lul op een slaatje.',
#   'reply_cnt': '1',
#   'retweet_cnt': '1',
#   'like_cnt': '1'},
#  {'username': 'Bennie Doorsnee',
#   'handle': '@benniedoorsnee',
#   'date': '2021-02-04T23:54:35.000Z',
#   'comment': 'Replying to \n@jelger_\n @llepoutre\n and 2 others',
#   'responding': 'Als jij kon kiezen tussen een vaccin met 55% bescherming of een vaccin met 91% bescherming, welke kies je? En welk vaccin zou dan beter zijn voor de volksgezondheid? Die van 55%, omdat het niet uit Rusland komt?',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': '1'},
#  {'username': 'IRMC',
#   'handle': '@IRMC16',
#   'date': '2021-02-04T23:54:03.000Z',
#   'comment': 'Blijkbaar een traditioneel vaccin, geen mRNA. Wel in een experimenteel stadium. Bescherming van slechts 60%.\n\nMaar veel belangrijker met betrekking tot "resultaat" is de omzet. Het gaat over miljarden euro\'s. Dat is het grootste belang.',
#   'responding': 'Quote Tweet\nNU.nl\n@NUnl\n · Feb 5\nLeidse farmaceut Janssen vraagt VS om versnelde goedkeuring coronavaccin: https://bit.ly/3pTWhok',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Zwiffi',
#   'handle': '@Zwiffi3',
#   'date': '2021-02-04T23:53:31.000Z',
#   'comment': '#vaccinatieplicht #ikvaccineerniet #ikprikhet\n\nBijwerkingen coronavaccin \n\nhttps://coronameldingen.lareb.nl/#/',
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': '1'},
#  {'username': 'CirkelsNL',
#   'handle': '@CirkelsNL',
#   'date': '2021-02-04T23:52:58.000Z',
#   'comment': 'Replying to \n@ChrisvdKieboom',
#   'responding': 'Is er nieuws, werkt het vaccin echt dan? Dus niet meer ziek noch besmettelijk na vaccinatie? \nDe enige gevaccineerde persoon die ik ken (jonge huisarts) kreeg precies op die dag corona...',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'DenvH',
#   'handle': '@DenvH1978',
#   'date': '2021-02-04T23:51:07.000Z',
#   'comment': 'Replying to \n@JanLangkamp\n and \n@JoostNiemoller',
#   'responding': 'Sorry dat ik het zeg en hoop het niet voor u, maar stel dat uw vader op die leeftijd morgen overlijdt. En dat komt dan niet door vaccin, maar gewoon door ouderdom. Vindt u het dan niet schandalig dat iemand anders dat vaccin niet heeft gekregen??? Dit is een gewetensvraag?',
#   'reply_cnt': '3',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'OnlyFacts',
#   'handle': '@matthijsj',
#   'date': '2021-02-04T23:51:04.000Z',
#   'comment': 'Replying to \n@RipVanW67340171\n @JoostNiemoller\n and \n@HenryJP5',
#   'responding': 'We was dus al immuun? Dus waarom dat vaccin?',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Franca',
#   'handle': '@BarbFranc',
#   'date': '2021-02-04T23:50:25.000Z',
#   'comment': 'Replying to \n@antikris77\n @erikotn\n and 2 others',
#   'responding': 'Dat zijn accessoires waarvan bekend zijn dat ze de veiligheid vergroten. Van het vaccin is niet bekend of het wel de groepsimmuniteit vergroot en er zijn een hoop vraagtekens over de veiligheid aangezien het niet uitvoerig is getest.',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': '1'},
#  {'username': 'DianaH',
#   'handle': '@DianaHogetoorn',
#   'date': '2021-02-04T23:47:05.000Z',
#   'comment': 'Replying to \n@liekelamb\n and \n@RichardLamb',
#   'responding': 'Naast virusvarianten, vaccineer-varianten, only in the Netherlands: “wel naalden geen spuit”, “naald te lang voor dunne mensen”, “voldoende vaccin te weinig prikkers” etc. etc.',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': '2'},
#  {'username': 'Provinco #uniawegermee',
#   'handle': '@provinco1',
#   'date': '2021-02-04T23:46:49.000Z',
#   'comment': 'Replying to \n@Showwhatishidde\n and \n@RvRavenstijn',
#   'responding': 'Volgens insiders het beste vaccin op de markt!?',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': '1'},
#  {'username': 'Pino',
#   'handle': '@Pino76148648',
#   'date': '2021-02-04T23:45:16.000Z',
#   'comment': 'Replying to \n@LHulule',
#   'responding': 'Oké, maar er gaan normaal gesproken ook wel eens mensen plotseling dood. Dat wil nog niet zeggen dat het perse door het vaccin komt he.',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Desmond Noordenstein',
#   'handle': '@noordenstein',
#   'date': '2021-02-04T23:43:47.000Z',
#   'comment': "Het is alsof het concept 'je kunt ziektes voorkomen en genezen met medicijnen' een totaal wezensvreemd concept is geworden. Iedereen schijnt te denken dat je niks tegen COVID-19 kunt doen, behalve afstand houden en op het vaccin wachten.",
#   'responding': '',
#   'reply_cnt': '1',
#   'retweet_cnt': '9',
#   'like_cnt': '18'},
#  {'username': 'ellen van ree',
#   'handle': '@ellenvanree',
#   'date': '2021-02-04T23:42:29.000Z',
#   'comment': 'Ik koop wel kleding van het merk Juffrouw Jansen. Die naam tovert een grijns op mijn tronie. Kweenie of ik dat vaccin van Jansen/Janssen wel wil. Stom hè.',
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': '1'},
#  {'username': 'Marjanne',
#   'handle': '@Marjann97025040',
#   'date': '2021-02-04T23:42:00.000Z',
#   'comment': 'Replying to \n@sari32264489',
#   'responding': 'Waarom laat je je ook in vredesnaam vaccineren. Wat je niet gaat beschermen tegen het virus! Het virus zit in het vaccin! Dus als dit niet gestopt wordt zitten we straks nog in een vele ergere lockdown mensen. Beter onderzoek doen naar het vaccin. En niet klakkeloos hugo geloven',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Orwell',
#   'handle': '@Showwhatishidde',
#   'date': '2021-02-04T23:41:24.000Z',
#   'comment': 'Lekker vaccin is dat toch ',
#   'responding': 'Quote Tweet\nArtsen Voor Vrijheid\n@ArtsenV\n · Feb 3\nAlle 78 bewoners van een verpleeghuis in centraal Spanje zijn positief getest op Covid-19 nadat ze hun eerste dosis van het Pfizer-BioNTech-vaccin hadden gekregen, en ten minste zeven mensen zijn overleden, bevestigde het personeel op maandag.  #vaccinat\n\nhttps://artsenvoorvrijheid.be/blog/2021/02/02/7-sterven-in-spaans-verzorgingstehuis-na-het-krijgen-van-pfizer-covid-19-prik-terwijl-alle-bewoners-positief-testen-op-virus-tweede-dosis-moet-nog-komen/…',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Edwin Jonker',
#   'handle': '@JonkerEdwin',
#   'date': '2021-02-04T23:40:44.000Z',
#   'comment': 'Replying to \n@JoostNiemoller',
#   'responding': 'Zolang nog niemand heeft laten zien dat het vaccin werkt en veilig is gaat die spuit er niet in. Alle vaccinatie missers worden nog steeds uit de media gehouden en ouderen die er aan overlijden heeft alles als oorzaak een onderliggende kwaal terwijl ze daarvoor niets markeerden',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'KLMNOP',
#   'handle': '@leykr',
#   'date': '2021-02-04T23:40:43.000Z',
#   'comment': 'Replying to \n@science_dirk\n @lenigeliefde\n and 2 others',
#   'responding': '"Je definieerde dat je meer kans moet hebben om te sterven door het vaccin dan door corona." dit is hopelijk omgekeerd?',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'LouLala',
#   'handle': '@LolaLa13883311',
#   'date': '2021-02-04T23:40:39.000Z',
#   'comment': 'Zal de NS meer diensten draaien als na juni na de verplichte vaccins de vaccin weigeraars naar speciale euthanasie locaties gebracht moeten orden?',
#   'responding': '',
#   'reply_cnt': '4',
#   'retweet_cnt': '2',
#   'like_cnt': '12'},
#  {'username': 'Mascha',
#   'handle': '@Mascha_NY',
#   'date': '2021-02-04T23:39:42.000Z',
#   'comment': 'Leidse farmaceut Janssen vraagt VS om versnelde goedkeuring coronavaccin\n\u2066\n@hugodejonge\n\u2069 \u2066\n@MinPres\n\u2069',
#   'responding': 'Leidse farmaceut Janssen vraagt VS om versnelde goedkeuring coronavaccin\nJanssen Biotech heeft de Amerikaanse Food and Drug Administration (FDA) om versnelde toestemming gevraagd om het coronavaccin van de Leidse farmaceut op de markt te brengen. Dat maakte het Amerikaa...\nnu.nl',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Steffie Franken',
#   'handle': '@steffiefranken',
#   'date': '2021-02-04T23:38:30.000Z',
#   'comment': 'Leidse maker coronavaccin vraagt VS om versnelde goedkeuring  via \n@Telegraaf',
#   'responding': 'Leidse maker coronavaccin vraagt VS om versnelde goedkeuring\nFarmaceut Janssen Biotech uit Leiden heeft de Amerikaanse geneesmiddelenautoriteit toestemming gevraagd om diens coronavaccin op de markt te zetten. Dat maakte het Amerikaanse moederbedrijf Johnson…\ntelegraaf.nl',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Bloemenmeisje',
#   'handle': '@Bloemenmeisje5',
#   'date': '2021-02-04T23:38:16.000Z',
#   'comment': 'Replying to \n@nuijten_rob\n and \n@IkNet',
#   'responding': 'Kinderen zijn in de huidige pandemie nog niet gevaccineerd, dat weet je toch?\nWel tijdens de Mexicaanse griep in 2009 met een overhaast ontwikkeld vaccin.\nEr heeft zich bij verscheidene kinderen na dat vaccin narcolepsie ontwikkeld.\nHierover lopen nog rechtszaken...',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': '4'},
#  {'username': 'Zwarte Roodstaart',
#   'handle': '@Roodstaart',
#   'date': '2021-02-04T23:37:46.000Z',
#   'comment': "Ben gebroken door advies van de \n@Gezondheidsraad\n. \n\nHet vaccin AZ voor mijn 'risicogroep' is niet voor deze groep getest. Risico: ernstiger beloop van COVID-19 of verergering van bestaande aandoening. Monitoring noodzakelijk. \n\nEr is een veilig vaccin, dat wordt niet ingezet.",
#   'responding': '',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': '2'},
#  {'username': 'Doorn',
#   'handle': '@top_grafisch',
#   'date': '2021-02-04T23:37:43.000Z',
#   'comment': 'Replying to \n@almeremarja\n @dafuck1980\n and \n@esther241101',
#   'responding': 'Terwijl meer dan 99,6% nauwelijks of geen last heeft van #covid19.\n\n60%-90% van 0,4%. Met een nauwelijks getest en in de USA niet goedgekeurd #Pfizer #Vaccin.\n\nEn er effectieve medicatie is tegen #covid19 (sinds 15 jaar).\n\nHet #vaccin heeft een ander doel !',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': '2'},
#  {'username': 'NU.nl',
#   'handle': '@NUnl',
#   'date': '2021-02-04T23:35:06.000Z',
#   'comment': 'Leidse farmaceut Janssen vraagt VS om versnelde goedkeuring coronavaccin:',
#   'responding': 'Leidse farmaceut Janssen vraagt VS om versnelde goedkeuring coronavaccin\nJanssen Biotech heeft de Amerikaanse Food and Drug Administration (FDA) om versnelde toestemming gevraagd om het coronavaccin van de Leidse farmaceut op de markt te brengen. Dat maakte het Amerikaa...\nnu.nl',
#   'reply_cnt': '9',
#   'retweet_cnt': '8',
#   'like_cnt': '26'},
#  {'username': 'Patrick',
#   'handle': '@1903George',
#   'date': '2021-02-04T23:34:57.000Z',
#   'comment': 'Replying to \n@Boreout',
#   'responding': 'Het vaccin geeft meer kans om zogenaamd erge ziekte te voorkomen. Het voorkomt niet dat je besmet raakt, en ook niet dat je een ander kan besmetten. Dat is een misconceptie.',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'JanHRo\ns',
#   'handle': '@JanHRoos',
#   'date': '2021-02-04T23:34:56.000Z',
#   'comment': 'Replying to \n@AgnostischWeten\n and \n@prinsrj',
#   'responding': "Jansen&jansen is NL-corona vaccin fabrikant. Was n virologe van aanwezig.\nFarid Azarkan, voorman van Denk. Harde debater, maar recht voor z'n raap. Slimme gast. Deed t ook goed bij slimste mens.",
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'R.J. Willemsen',
#   'handle': '@RJWillemsen1',
#   'date': '2021-02-04T23:33:40.000Z',
#   'comment': 'Replying to \n@telegraaf',
#   'responding': 'Dan kan Sputnik of NL dit toch ook vragen voor Corona Vaccin Sputnik V. Andere vraag als Janssen Biotech toestemming krijgt aan de Amerikaanse geneesmiddelenautoriteit mag dit dan ook aan de NL se EU worden aangeboden voor in te enten?',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Marinus',
#   'handle': '@Marinus_vd_Hoek',
#   'date': '2021-02-04T23:33:21.000Z',
#   'comment': 'Replying to \n@Jinek_RTL',
#   'responding': 'Toch een vraagje, als we gevaccineerd zijn, zijn we toch beschermt? Dan is het toch niet heel erg dat een enkeling niet is gevaccineerd? Waarom dan een vaccin-paspoort of nog steeds alle maatregelen handhaven als dat paspoort er niet komt. waarom iemand weigeren.. ',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': '2'},
#  {'username': 'Se7en',
#   'handle': '@Oceanse7en',
#   'date': '2021-02-04T23:33:11.000Z',
#   'comment': 'Replying to \n@Robin14003352\n @Jinek_RTL\n and \n@F_azarkan',
#   'responding': 'Je begrijpt het duidelijk niet. Een gevacineerde is niet 100% immuun na een tijd neemt effectiviteit af. De gewoon iedereen vaccineren stel je niet aan. Tenzij je jouw grootouders, ooms en tantes wil besmetten met corona neem het vaccin gewoon. Simpel.',
#   'reply_cnt': '6',
#   'retweet_cnt': '',
#   'like_cnt': '2'},
#  {'username': 'M',
#   'handle': '@noiramdlow',
#   'date': '2021-02-04T23:32:35.000Z',
#   'comment': 'Europa heeft nog geen contact opgenomen met het seruminstituut India waar alle vaccins klaar liggen. Zij maken ook voor astrazenica! Instituut wacht op tel!! #CNN #AstraZeneca #vaccin \n@SerumInstIndia',
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Rip van Winkel',
#   'handle': '@RipVanW67340171',
#   'date': '2021-02-04T23:32:09.000Z',
#   'comment': 'Replying to \n@HenryJP5\n and \n@JoostNiemoller',
#   'responding': 'ik ben het met u eens. Ik vind het idioot om 90+ers in te enten met een vaccin in een testfase.',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': '3'},
#  {'username': 'Mister_D',
#   'handle': '@AndroidDevil83',
#   'date': '2021-02-04T23:31:53.000Z',
#   'comment': 'Replying to \n@superjan',
#   'responding': 'Hoe verkoop je vaccins.\n1 creeër een virus\n2 veroorzaakt veel paniek, tref absurde maatregelen\n3 breng gelijkelijk de vaccins op de markt\n4 veel mensen willen het vaccin en het geld stroomt binnen.',
#   'reply_cnt': '2',
#   'retweet_cnt': '1',
#   'like_cnt': '8'},
#  {'username': 'KlaasV',
#   'handle': '@KlaVeld',
#   'date': '2021-02-04T23:31:47.000Z',
#   'comment': 'Onverwacht: \n\nDeel van mensen met overgewicht krijgt drie prikken tegen corona van GGD. \n\nNaald met vaccin blijkt te kort om spier te bereiken.\n\n#coronavaccin',
#   'responding': 'Quote Tweet\nDagblad v/h Noorden\n@dvhn_nl\n · Feb 4\nEen deel van de Nederlanders met overgewicht heeft de eerste coronaprik met een te korte naald gekregen en kan daarom bij de tweede injectie een uitnodiging voor een derde vaccinatie verwachten. Dat bevestigen de GGD Drenthe en de landelijke GGD GHOR https://buff.ly/39NCcdI',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Lambert Lepoutre',
#   'handle': '@llepoutre',
#   'date': '2021-02-04T23:31:23.000Z',
#   'comment': 'Replying to \n@jelger_\n @benniedoorsnee\n and 2 others',
#   'responding': 'Als onze volksgezondheid gebaat is bij het Russisch vaccin, zou ik daar niet voor weglopen. Leveranciers van onbesproken gedrag vind je niet gemakkelijk.',
#   'reply_cnt': '2',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'TechSponge',
#   'handle': '@bruggezot',
#   'date': '2021-02-04T23:30:51.000Z',
#   'comment': 'Als ik me laat #vaccineren, dan wil ik eerst al mijn #vragen beantwoord zien en de #bijsluiters kunnen lezen. Vervolgens, nogmaals, áls ik me laat vaccineren, bepaal ik zelf en niemand anders het merk #vaccin.',
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'JustABuzz',
#   'handle': '@Buzzerzz78',
#   'date': '2021-02-04T23:27:11.000Z',
#   'comment': 'Replying to \n@ciaudias\n and \n@JoostNiemoller',
#   'responding': 'En volgend jaar en het jaar daarna en daarna zeker de hele wereld elke keer weer vaccineren voor elke nieuwe mutant die niet reageert op het vaccin. Wat een zwaktebod. Aan het vaccininfuus van de bigpharma\nmooi niet.',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': '3'},
#  {'username': 'Poppenkast',
#   'handle': '@Schiedam_wtf',
#   'date': '2021-02-04T23:26:46.000Z',
#   'comment': 'Vaccin- en genderwappies die hele bevolkingsgroepen uitsluiten. Ik vind daar wat van\n #MIAUW',
#   'responding': 'Quote Tweet\nJelmer Visser\n@DieTukkerfries\n · Feb 4\nOh ja, organiseer zelf natuurlijk ook een evenement.\n\nVoor MIAUW wordt een vaccinatiepas sowieso verplicht. Want dat bepaal ik.\nShow this thread',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''}]

# %%
len(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c6201f8cef64> in <module>
# ----> 1 len(data)
#
# NameError: name 'data' is not defined

# %%
with open("DataCollection_Twitter.csv", "w", newline="", encoding='utf-8') as csv_file:
  cols = ['username', 
             'handle', 
             'date',
             'comment', 
             'responding', 
             'reply_cnt', 
             'retweet_cnt', 
             'like_cnt'] 
  writer = csv.DictWriter(csv_file, fieldnames=cols, restval='MISSING')
  writer.writeheader()
  writer.writerows(data)
