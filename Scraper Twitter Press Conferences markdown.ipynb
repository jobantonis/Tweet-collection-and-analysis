# %% [markdown]
# # Twitter scraper COVID vaccine press conferences within the Netherlands

# %% [markdown]
# We built a Twitter scraper in order to find out the sentiment towards to COVID-19 vaccine in the Netherlands, within the time frames surrounding the Dutch governments' Press Conferences. Herewith we want to measure the influence of the regulations regarding COVID-19 on the attitude people have towards COVID-19 vaccines.
#
# Our scraper results in a CSV file, containing the following entities:
# - Dutch tweets containing the following keywords: *coronavaccin, corona_vaccin, covidvaccin, covid_vaccin, covid_vaccine, covidvaccine, coronavaccine, covid_vaccine*
# - Specific dates the tweets were posted (around the persconferences (3 days before and 3 days after), *datums + timeframe n.t.b. https://www.rijksoverheid.nl/onderwerpen/coronavirus-covid-19/coronavirus-beeld-en-video/videos-persconferenties*)
# - Content of the tweets
# - User ID *anoniem gemaakt d.m.v. ...*
#
# ##Datum nog veranderen!!!

# %% [markdown]
# For our code, we decided to use Selenium because Twitter is a dynamic webpage where we need to mimic scrolling like a Twitter user.
# Therefore, we first have to download and import some drivers and prerequisites.

# %%
import csv
import selenium.webdriver   
from getpass import getpass
from time import sleep
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# Then, we wrote a function in order to get multiple tweets. We used the .find()-function in order to find specific elements in the source code of the website. Below, we inserted 2 pictures, showing examples of how we found the specific elements (for username and comment). The '.text'-function makes sure we copy the text belonging to the element we were looking for.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/jobantonis/Tremendously-awesome-repository/main/Screenshot%202021-03-11%20at%2017.17.12.png" align="center" width=60%/>

# %%
def get_tweet_data(card):
    username = card.find_element_by_xpath('.//span').text
    try:
        handle = card.find_element_by_xpath('.//span[contains(text(), "@")]').text 
    except NoSuchElementException:
        return
    
    try:
        postdate = card.find_element_by_xpath('.//time').get_attribute('datetime')
    except NoSuchElementException:
        return
    
    comment = card.find_element_by_xpath('.//div[2]/div[2]/div[1]').text
    responding = card.find_element_by_xpath('.//div[2]/div[2]/div[2]').text
    #text = comment + responding
    reply_cnt = card.find_element_by_xpath('.//div[@data-testid="reply"]').text
    retweet_cnt = card.find_element_by_xpath('.//div[@data-testid="retweet"]').text
    like_cnt = card.find_element_by_xpath('.//div[@data-testid="like"]').text
    
    tweet = {'username':username, 
             'handle':handle, 
             'date': postdate,
             'comment': comment, 
             'responding': responding, 
             'reply_cnt':reply_cnt, 
             'retweet_cnt': retweet_cnt, 
             'like_cnt': like_cnt}
    return(tweet)

# %% [markdown]
# We use Selenium, and therefore have to choose a browser in which we are going to open Twitter. We decided to use Chrome, so we set our Driver to Chrome.

# %%
driver = selenium.webdriver.Chrome()

# %% [markdown]
# We do not want to log into Twitter. Therefore, we chose to use the URL containing the keywords and the specific dates we want to search for. Next, we open the Driver into Chrome.

# %%
driver.get('https://twitter.com/search?q=(coronavaccin%20OR%20corona_vaccin%20OR%20covidvaccin%20OR%20covid_vaccin%20OR%20corona_vaccine%20OR%20coronavaccine%20OR%20covidvaccine%20OR%20covid_vaccine)%20lang%3Anl%20until%3A2020-04-02%20since%3A2020-03-28&src=typed_query&f=live') 
#driver.maximize_window()

# %% [markdown]
# Next, we want to fill the data with our input. Therefore, we create a list called 'data'. Furthermore, since it is a dynamic website which is accessed through scrolling through the site, we want to make sure we do not add the same tweets twice, therefore the function set(), called tweet_ids is added. Lastly, we added a function that executes the script and stops when we are at the last page.

# %%
data = [] #needed to fill a string with data
tweet_ids = set() #Used in order to mitigate scraping duplicate tweets caused by possible increasing number of tweets per scroll 
last_position = driver.execute_script("return window.pageYOffset;") #For tracking scroll position, breaking out of loop if end is reached
scrolling = True

# %% [markdown]
# While scrolling, we want to make sure to capture our data from the tweets we encounter. After that, we actually begin to scroll down the pages. Since we are aware that there is a possibility that our internet laggs in between because of poor internet connection, we made sure our scraper tries to scroll twice before it is disregarded.

# %%
while scrolling:
    
    page_cards = driver.find_elements_by_xpath('//div[@data-testid="tweet"]') #First div with which the scraper encounters a tweet
    for card in page_cards[-15:]: # used -15, since we assume there are 15 tweets loaded each time
        tweet = get_tweet_data(card) #get 15 tweets per reload
        if tweet not in data:
            data.append(tweet)    
        
 #       if tweet:
 #           tweet_id = tweet #make 1 tweet of the separate words used in the tweet
 #           if tweet_id not in tweet_ids: #Make sure you do not capture the same tweet twice, by only appending tweets that you haven't added before. 
 #               tweet_ids.add(tweet_id) #to the set() function we add tweet_ids
 #               data.append(tweet) #add tweets to data list

    scroll_attempt = 0 #used as sometimes due to lag scrolling will not register, so we allow for number of scroll attempts
    while True:
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        sleep(1) #giving program time to load before scraping
        curr_position = driver.execute_script("return window.pageYOffset;")
        if last_position == curr_position: #breaks out of loop if current and last scroll positions are the same
            scroll_attempt += 1 
            #2 attempts to check if it is the end of the page, since it is also possible that the scraper laggs because of poor internet connection.
            if scroll_attempt >= 3: 
                scrolling = False
                break
            else: 
                sleep(2) 
        else:
            last_position = curr_position #makes sure the loop ends
            break

# %% [markdown]
# Copy the data to a CSV file, creating headers and writing data towards the file using the following code:

# %%
data
# Out:
# [{'username': 'Koos Dirkse',
#   'handle': '@koosdirkse',
#   'date': '2020-03-15T23:49:15.000Z',
#   'comment': "De man heeft werkelijk geen idee waar hij mee bezig is!\n‘Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '6',
#   'retweet_cnt': '5',
#   'like_cnt': '6'},
#  {'username': 'Victor Robert Poppenburg',
#   'handle': '@secondhomemondi',
#   'date': '2020-03-15T23:36:12.000Z',
#   'comment': '‘Trump probeert coronavaccin te kapen van Duits biotechbedrijf’. https://fd.nl/ondernemen/1338050/trump-probeert-coronamedicijn-te-kapen-van-duits-biotechbedrijf?utm_medium=social&utm_source=twitter&utm_campaign=SHR_ARTT_20200316&utm_content=ondernemen… #FD #Biotechnologie',
#   'responding': '‘Trump probeert coronavaccin te kapen van Duits biotechbedrijf’\nIn de wedloop voor een coronavaccin dreigt een conflict tussen de Verenigde Staten en Duitsland.\nfd.nl',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': '𝔼𝕟𝕘𝕖𝕝𝕚',
#   'handle': '@ilegne',
#   'date': '2020-03-15T23:19:43.000Z',
#   'comment': 'de VS laten geen enkele Europeaan meer het land in maar willen wel het Duitse bedrijf dat het #Corona vaccin ontwikkelt naar VS halen + exclusieve rechten hebben. Rug recht houden Duitsland. Sodemieter op Trump! #Coronavirus #CureVac #COVID19',
#   'responding': 'Citeer Tweet\nBericht aus Berlin\n@ARD_BaB\n · 15 mrt. 2020\n"Deutschland steht nicht zum Verkauf" – so @peteraltmaier #CDU im #BerichtausBerlin zum vermeintlichen Streit mit den USA um Impfstoff. #Coronavirus #CureVac',
#   'reply_cnt': '1',
#   'retweet_cnt': '1',
#   'like_cnt': '1'},
#  {'username': 'Toon de Laaf #FB#PE#Greens',
#   'handle': '@Toon_de_Laaf',
#   'date': '2020-03-15T23:18:33.000Z',
#   'comment': "Hoe diep kun je zakken? 'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… (via \n@NUnl\n)",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Wouter Zwart NOS',
#   'handle': '@WouterZwart',
#   'date': '2020-03-15T18:54:52.000Z',
#   'comment': 'Minister Seehofer lijkt bericht te bevestigen dat Amerika probeert met grote geldsommen het Duitse bedrijf CureVac binnen te hengelen, dat werkt aan een #corona -vaccin: “ik heb vandaag van meerdere kanten hierover gehoord. Dat bespreken we morgen in het crisisberaad.”',
#   'responding': '',
#   'reply_cnt': '6',
#   'retweet_cnt': '13',
#   'like_cnt': '18'},
#  {'username': 'ertugrul',
#   'handle': '@simbad123456789',
#   'date': '2020-03-15T18:00:48.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' | NU - Het laatste nieuws het eerst op\n\nDat dus nooit! Monopolie in handen van een dergelijk labiele leider!\n\nhttp://NU.nl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'thingsbyy',
#   'handle': '@Thingsbyy',
#   'date': '2020-03-15T17:57:35.000Z',
#   'comment': "http://cutt.ly/8e5346v 'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' http://dlvr.it/RRxBDH http://cutt.ly/8e5346v #Subscribe #YouTube",
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Laurent Bruning',
#   'handle': '@LBruningNL',
#   'date': '2020-03-15T17:41:52.000Z',
#   'comment': 'Regering Trump probeert exclusieve rechten op Coronavaccin te verkrijgen https://krapuul.nl/buitenland-2/2745947/regering-trump-probeert-exclusieve-rechten-op-coronavaccin-te-verkrijgen/…',
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '1',
#   'like_cnt': ''},
#  {'username': 'Dijk',
#   'handle': '@klaskebrabant',
#   'date': '2020-03-15T17:32:54.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl\n ##amerika first. Zou een grof schandaal zijn",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Marja Feltkamp',
#   'handle': '@MarjaFeltkamp',
#   'date': '2020-03-15T17:12:35.000Z',
#   'comment': "This guy is utterly disgusting.\n\n'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… (via \n@NUnl\n)",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'jim faas\n(@\n)',
#   'handle': '(@',
#   'date': '2020-03-15T17:08:38.000Z',
#   'comment': " Wisten we al, maar wat is die \n@realDonaldTrump\n toch een ongelooflijke L*L\n’Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' \n Als dit waar is, mag het GROOTS op de voorpagina van alle kranten\n\nhttps://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '1',
#   'like_cnt': '1'},
#  {'username': 'vaccinaddy',
#   'handle': '@HKH',
#   'date': '2020-03-15T17:01:21.000Z',
#   'comment': "Ik begrijp dat dat #makeamericagreatagain door  #givehimachance toch niet zo’n succes is. \n\n'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Gerrie Eijkhout',
#   'handle': '@Eijkhout',
#   'date': '2020-03-15T15:25:16.000Z',
#   'comment': "Wanneer gaan wij als EU nou eens een keer opstaan en eens keer assertief reageren? \n@MinPres\n@LodewijkA\n @TimmermansEU\n'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… (via \n@NUnl\n)",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Maarten.',
#   'handle': '@PTeazer52',
#   'date': '2020-03-15T15:23:07.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' Trump gaat ook al Hamsteren, wat een egoïstische Rat.",
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Joyce',
#   'handle': '@djoiszle',
#   'date': '2020-03-15T15:21:16.000Z',
#   'comment': " 'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Robert Pallencaöe',
#   'handle': '@rubbie14',
#   'date': '2020-03-15T15:20:00.000Z',
#   'comment': "Dictators be like.. \n‘Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Rob',
#   'handle': '@Rob43782242',
#   'date': '2020-03-15T15:19:05.000Z',
#   'comment': 'Volgens het nieuws probeert de VS het alleen recht voor een Corona vaccin van een Duits bedrijf te kopen. Lonkt het grote geld? In dat geval moet Europa de betrekkingen met de VS herzien.',
#   'responding': 'Corona: USA will Zugriff auf deutsche Impfstoff-Firma - WELT\nDie Tübinger Firma CureVac forscht unter Hochdruck an einem Corona-Impfstoff. Nach WELT AM SONNTAG-Informationen will sich die US-Regierung die Rechte daran exklusiv sichern. Die deutsche Regierung...\nwelt.de',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Ronny Ligot',
#   'handle': '@ronnyligot',
#   'date': '2020-03-15T15:13:42.000Z',
#   'comment': '@realDonaldTrump\n Trump probeert de Duitse wetenschappers die aan het coronavaccin werken te lokken met hoge financiële beloftes.\nAls je het wil hebben maak het dan zelf! het is al erg genoeg dat er in europa en andere continenten mensen sterven.\ndat zegt genoeg over jouw.',
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Gert -K',
#   'handle': '@mink76',
#   'date': '2020-03-15T15:06:45.000Z',
#   'comment': "Serieus? Hopelijk fakenews. Anders grote egoïst!\n'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… (via \n@NUnl\n)",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Arnold van der Kluft',
#   'handle': '@Voorzeespeurder',
#   'date': '2020-03-15T15:03:11.000Z',
#   'comment': 'Regering Trump probeert exclusieve rechten op Coronavaccin te verkrijgen https://krapuul.nl/buitenland-2/2745947/regering-trump-probeert-exclusieve-rechten-op-coronavaccin-te-verkrijgen/…',
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '3',
#   'like_cnt': ''},
#  {'username': 'Peter Heisterkamp',
#   'handle': '@PHeisterkamp',
#   'date': '2020-03-15T15:01:16.000Z',
#   'comment': "Daad van agressie: 'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… (via \n@NUnl\n)",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Johan Heerema',
#   'handle': '@JanJohanHeerema',
#   'date': '2020-03-15T14:34:45.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\n#puuregoïsme #Americafirst #idioot",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': '@Criticomm',
#   'handle': '@Criticomm',
#   'date': '2020-03-15T14:23:25.000Z',
#   'comment': "Als er iets #treurig is dan dit wel: wat gaan \n@MinPres\n , #Duitsland en de rest van #Europa hier aan doen? #Coronavirusnl   \n@nos\n http://NU.nl: 'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'.\nhttps://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html…\n\nvia \n@GoogleNews",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Marco Knulst RBA',
#   'handle': '@mjknulst',
#   'date': '2020-03-15T14:22:57.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '1',
#   'like_cnt': ''},
#  {'username': 'Arthur',
#   'handle': '@King66Arthur',
#   'date': '2020-03-15T14:22:23.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nFucking A hole Trump",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': '1'},
#  {'username': 'Jααρ ναи Ðιjк',
#   'handle': '@jkavandijk',
#   'date': '2020-03-15T14:20:35.000Z',
#   'comment': 'Niet normaal meer: \nTrump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS',
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Olaf Agterbosch',
#   'handle': '@ollyag',
#   'date': '2020-03-15T14:20:34.000Z',
#   'comment': "De stupide kwaadaardigheid van deze man kent geen grenzen...\n‘Trump wil Duits bedrijf kopen voor exclusiviteit #coronavaccin in VS'\n#COVIDー19\n#Coronavirusnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Jenny Lamers',
#   'handle': '@engelsetheemuts',
#   'date': '2020-03-15T14:19:51.000Z',
#   'comment': "Woest kan ik hierom worden!!!\n\n'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Jacqcinati',
#   'handle': '@JacquelineBlom6',
#   'date': '2020-03-15T13:43:23.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' | NU - Het laatste nieuws het eerst op http://NU.nl https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html…\nWat is die Trump toch een nazi zeg! Hoe haalt hij het in zijn hoofd! En dan mag hij zeker bepalen wie leeft en sterft ",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Martijn Leeftink',
#   'handle': '@amleeftink',
#   'date': '2020-03-15T13:42:56.000Z',
#   'comment': 'VS (lees #Trump) wil exclusieve rechten voor corona vaccin kopen, staat in dit liveblog. Laten we hopen dat de ontwikkelaars menselijker zijn dan Trumps egoïsme en mensenlevens meee waard vinden dan een zak met geld. -',
#   'responding': "Scholen en eet- en drinkgelegenheden drie weken dicht, 'gepaste afstand' bewaren\nLees hier al het nieuws over het coronavirus.\nnos.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '1',
#   'like_cnt': ''},
#  {'username': '𝓢𝓽𝓮𝓿𝓮𝓷 𝓛𝓮𝓬𝓵𝓾𝔂𝓼𝓮',
#   'handle': '@slecluyse',
#   'date': '2020-03-15T13:39:23.000Z',
#   'comment': 'Wtf?!\n\n\u2066\n@realDonaldTrump\n\u2069 probeert Duits #Corona-vaccin exclusief voor VS te pakken te krijgen',
#   'responding': 'Donald Trump probeert Duits vaccin exclusief voor VS te pakken te krijgen\nDe Amerikaanse president Donald Trump probeert de rechten op een vaccin tegen het coronavirus, dat getest wordt in Duitsland, exclusief voor de VS te pakken te krijgen. De Duitse regering probeert...\nhln.be',
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'kees de zeeuw',
#   'handle': '@kees_de_zeeuw',
#   'date': '2020-03-15T13:34:50.000Z',
#   'comment': 'Iedereen die heeft gezegd dat #Trump niet deugt, heeft dus gelijk. ‘VS probeert rechten #corona #vaccin te kopen’ \nDe Amerikanen willen exclusief de rechten op een vaccin kopen om het exclusief voor de VS te bemachtigen. #coronavirus',
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '2',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Dave Anakotta',
#   'handle': '@DaveAnakotta',
#   'date': '2020-03-15T13:33:34.000Z',
#   'comment': '‘Trump probeert coronavaccin te kapen van Duits biotechbedrijf’. https://fd.nl/ondernemen/1338050/trump-probeert-coronamedicijn-te-kapen-van-duits-biotechbedrijf?utm_medium=social&utm_source=twitter&utm_campaign=SHR_ARTT_20200315&utm_content=ondernemen… #FD #Biotechnologie',
#   'responding': '‘Trump probeert coronavaccin te kapen van Duits biotechbedrijf’\nIn de wedloop voor een coronavaccin dreigt een conflict tussen de Verenigde Staten en Duitsland.\nfd.nl',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'diededus',
#   'handle': '@diededus',
#   'date': '2020-03-15T13:33:10.000Z',
#   'comment': "Trump doet wat ie altijd doet,  maar dat bedrijf is natuurlijk pas écht asociaal. \n'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… (via \n@NUnl\n)",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Kees Koenen',
#   'handle': '@keeskoenen',
#   'date': '2020-03-15T13:31:53.000Z',
#   'comment': 'Als antwoord op \n@WBHoekstra\n en \n@cdavandaag',
#   'responding': "Stelling: een ontwikkeld vaccin en het onderzoek dat ertoe geleid heeft zou als #OpenSource gepubliceerd moeten worden. Dus het 'recept' mag niet geheim zijn! Zo kan elk bedrijf dat dat wil, het produceren. #COVID2019NL #corona #vaccin",
#   'reply_cnt': '',
#   'retweet_cnt': '1',
#   'like_cnt': ''},
#  {'username': 'Jeroen van der Harst',
#   'handle': '@jerhar_',
#   'date': '2020-03-15T12:58:40.000Z',
#   'comment': "ASOCIAL!!!!! \n@realDonaldTrump\n@POTUS\n'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… (via \n@NUnl\n)",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': '1'},
#  {'username': 'Bianca',
#   'handle': '@BiancaPrins',
#   'date': '2020-03-15T12:53:12.000Z',
#   'comment': "Wanneer #COVIDー19 het slechtste in politici en de mens naar boven brengt \n'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… (via \n@NUnl\n)",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '2',
#   'retweet_cnt': '3',
#   'like_cnt': '5'},
#  {'username': 'Robin',
#   'handle': '@Robmpvt',
#   'date': '2020-03-15T12:47:25.000Z',
#   'comment': "Eigen volk eerst .... 'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Nic',
#   'handle': '@gpnp_nic',
#   'date': '2020-03-15T12:46:25.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl\n En als het dan niet lukt om een deal te sluiten, zie artikel, dan zorg ik, Pinokkio Trump, er persoonlijk voor dat je als CEO aan de kant wordt geschoven...",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Minou op den Velde',
#   'handle': '@MinouopdenVelde',
#   'date': '2020-03-15T12:44:58.000Z',
#   'comment': "Trump neemt 'America First' zo serieus dat hij alleen Amerikanen een corona-vaccin gunt. Goed om te weten voor alle internationale leiders die de komende jaren nog met hem onderhandelen, over wat dan ook.",
#   'responding': '',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Bianca',
#   'handle': '@MissNoNickName',
#   'date': '2020-03-15T12:44:07.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' | NU - Het laatste nieuws het eerst op http://NU.nl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Gert Jan ● Waterink',
#   'handle': '@GertJanWaterink',
#   'date': '2020-03-15T12:40:36.000Z',
#   'comment': "Een gotspe dat dit gebeurt. De vraag doemt, helaas, dan ook op: Wie gun je het Corona-vaccin meer? Onze Oosterburen/EU? Of Trump's Amerika? Iedereen natuurlijk! Maar Trump's cynisme en ineffectiviteit als leider versterkt onherroepelijk dit soort dystopie:",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Derek',
#   'handle': '@dereksmit83',
#   'date': '2020-03-15T12:39:01.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html…",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Monique Netherlands',
#   'handle': '@kommacoaching',
#   'date': '2020-03-15T12:38:41.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Petra',
#   'handle': '@Gazendam_Petra',
#   'date': '2020-03-15T12:16:23.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '2',
#   'retweet_cnt': '2',
#   'like_cnt': '1'},
#  {'username': 'Marion',
#   'handle': '@mfswager',
#   'date': '2020-03-15T12:15:33.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nHet zal toch niet waar zijn! Dit zou een rücksichtsloze asociale actie zijn van \u2066\n@POTUS\n\u2069",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'GoaTrance.NET',
#   'handle': '@GoaTranceNET',
#   'date': '2020-03-15T12:14:03.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'",
#   'responding': 'Het volgende materiaal bevat mogelijk gevoelige content. Instellingen wijzigen\nBekijken',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Lars Sørensen',
#   'handle': '@larssorensen',
#   'date': '2020-03-15T12:13:41.000Z',
#   'comment': "OMG.. 'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '1',
#   'like_cnt': '1'},
#  {'username': 'Berendsje Westra',
#   'handle': '@fictionbw',
#   'date': '2020-03-15T12:12:06.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'christiaan holland',
#   'handle': '@christiaanholla',
#   'date': '2020-03-15T12:11:14.000Z',
#   'comment': "Dit is wel een hele perverse invulling van het motto America First. #Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'Alex van Reeuwijk',
#   'handle': '@alexvanreeuwijk',
#   'date': '2020-03-15T12:10:08.000Z',
#   'comment': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\n\nDit is toch wel het begin van het einde van de trans-Atlantische relatie zolang deze man ‘In Office’ wordt gehouden.",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '1',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'CRYPTO LION',
#   'handle': '@MaarNormaal',
#   'date': '2020-03-15T12:10:03.000Z',
#   'comment': 'Als antwoord op \n@LieselottePost\n en \n@NOS',
#   'responding': 'influenza heeft jaarlijks tussen de 10k en 2k sterfgevallen. En dat is mét vaccine en antistoffen. Die hebben we niet voor corona dus daarom moeten we wel andere maatregelen treffen. En corona is niet ipv de griep maar komt er bovenop.',
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''},
#  {'username': 'A.J. van der Veen',
#   'handle': '@swartkapke',
#   'date': '2020-03-15T12:09:46.000Z',
#   'comment': " '#Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS' #COVIDー19 https://nu.nl/coronavirus/6037613/trump-wil-duits-bedrijf-kopen-voor-exclusiviteit-coronavaccin-in-vs.html… via \n@NUnl",
#   'responding': "'Trump wil Duits bedrijf kopen voor exclusiviteit coronavaccin in VS'\nDe Amerikaanse regering wil een Duits bedrijf kopen dat bezig is met de ontwikkeling van een vaccin tegen COVID-19, schrijft de Duitse krant Die Welt zondag op basis van bronnen dicht bij de Duitse...\nnu.nl",
#   'reply_cnt': '',
#   'retweet_cnt': '',
#   'like_cnt': ''}]

# %%
len(data)
# Out:
# 132

# %%
with open("coronavaccin_tweetsuntil%3A2020-04-02%20since%3A2020-03-28.csv", "w", newline="", encoding='utf-8') as csv_file:
  cols = ['username', 
             'handle', 
             'date',
             'comment', 
             'responding', 
             'reply_cnt', 
             'retweet_cnt', 
             'like_cnt'] 
  writer = csv.DictWriter(csv_file, fieldnames=cols, restval='MISSING')
  writer.writeheader()
  writer.writerows(data)
